# %%
import pandas as pd
import os
import numpy as np

import arcpy

#import arcgis libraries
from arcgis.gis import *
gis = GIS()

# %%
# IMPORTANT!!! download and save to data folder : https://gis.utah.gov/data/planning/water-related-land/
dirWRLUData = r"data\Water-Related-Land-Use"
fnWRLUshp = 'WaterRelatedLandUse.shp'
dFilterField = 'Landuse'
dFilterValues = ['Agricultural']

# %%
sdfWaterRelatedLandUse = pd.DataFrame.spatial.from_featureclass(os.path.join(dirWRLUData,fnWRLUshp))
sdfWaterRelatedLandUse
# Out:
#            FID  OBJECTID  LUID       Landuse CropGroup Descriptio IRR_Method  \
# 0            0         1     0  Agricultural  Hay/Turf    Alfalfa       Drip
# 1            1         2     0  Agricultural  Hay/Turf    Alfalfa      Flood
# 2            2         3     0  Agricultural  Hay/Turf    Alfalfa      Flood
# 3            3         4     0  Agricultural  Hay/Turf    Alfalfa      Flood
# 4            4         5     0  Agricultural  Hay/Turf    Alfalfa      Flood
# ...        ...       ...   ...           ...       ...        ...        ...
# 332473  332473    332474     0         Water      None  Wet Flats       None
# 332474  332474    332475     0         Water      None  Wet Flats       None
# 332475  332475    332476     0         Water      None  Wet Flats       None
# 332476  332476    332477     0         Water      None  Wet Flats       None
# 332477  332477    332478     0         Water      None  Wet Flats       None
#
# ...

# %%
sdfAg = sdfWaterRelatedLandUse[(sdfWaterRelatedLandUse['Landuse']=='Agricultural') & (sdfWaterRelatedLandUse['County'].isin(['Box Elder','Weber','Davis','Salt Lake']))]
sdfAg
# Out:
#            FID  OBJECTID  LUID       Landuse    CropGroup Descriptio  \
# 7            7         8     0  Agricultural     Hay/Turf    Alfalfa
# 27          27        28     0  Agricultural     Hay/Turf    Alfalfa
# 29          29        30     0  Agricultural     Hay/Turf    Alfalfa
# 30          30        31     0  Agricultural     Hay/Turf    Alfalfa
# 33          33        34     0  Agricultural     Hay/Turf    Alfalfa
# ...        ...       ...   ...           ...          ...        ...
# 295354  295354    295355     0  Agricultural  Small Fruit     Grapes
# 295356  295356    295357     0  Agricultural  Small Fruit     Grapes
# 295357  295357    295358     0  Agricultural  Small Fruit     Grapes
# 295358  295358    295359     0  Agricultural  Small Fruit     Grapes
# 295360  295360    295361     0  Agricultural  Small Fruit     Grapes
#
#        IRR_Method      Acres State     County  ...                  SubArea  \
# ...

# %%
sdfAg.spatial.to_featureclass(os.path.join('intermediate','agricultural.shp'))
# Out:
# c:\Users\bhereth\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone-again-again\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 'e:\\WebAppBuilderForArcGIS_v2.20\\server\\apps\\15\\_dataprep\\intermediate\\agricultural.shp'
